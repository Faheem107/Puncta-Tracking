# %%
# import libraries, modules
import numpy as np, matplotlib.pyplot as plt, pandas as pd, matplotlib.colors, csv, import_ipynb
from SortRates import sort_clean
from BinningPhasePortrait import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 # import libraries, modules
# ----> 2 import numpy as np, matplotlib.pyplot as plt, pandas as pd, matplotlib.colors, csv, import_ipynb
#       3 from SortRates import sort_clean
#       4 from BinningPhasePortrait import *
#
# ModuleNotFoundError: No module named 'import_ipynb'

# %%
# data sorting, cleaning ##MyD88, RelA

sort_clean(filename='/scratch/brp306/ActinWasp/AW_Data/FinalTable.csv', 
           savelocation = '/scratch/brp306/ActinWasp/AW_Data/FinalTableRates.csv',
           time_between_frames = 1., diff = 1, exceptional_file = False)
# Out:
# 'For /scratch/brp306/ActinWasp/AW_Data/FinalTable.csv, rates are saved at /scratch/brp306/ActinWasp/AW_Data/FinalTableRates.csv'

# %%
# binning

binning(filename='/scratch/brp306/ActinWasp/AW_Data/FinalTableRates.csv', 
        savelocation = '/scratch/brp306/ActinWasp/AW_Data/FinalTableBins.csv', 
        diff = 1, x_bin_size = 20000, y_bin_size = 2000, 
        min_frame = None, max_frame = None)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 3
#       1 # binning
# ----> 3 binning(filename='/scratch/brp306/ActinWasp/AW_Data/FinalTableRates.csv',
#       4         savelocation = '/scratch/brp306/ActinWasp/AW_Data/FinalTableBins.csv',
#       5         diff = 1, x_bin_size = 20000, y_bin_size = 2000,
#       6         min_frame = None, max_frame = None)
#
# File <string>:23, in binning(filename, savelocation, diff, x_bin_size, y_bin_size, min_frame, max_frame)
#
# ValueError: min() arg is an empty sequence

# %%
# phase portrait
#plt.style.use('seaborn-v0_8-darkgrid')
Phase_portrait(
    filename = '/scratch/brp306/ActinWasp/AW_Data/FinalTableBins.csv',
    savelocation = '/scratch/brp306/ActinWasp/AW_Data/phaseportrait',
    diff = 1, threshold = 10,
    heatmap = 'counts_in_bin')

#'/scratch/brp306/IS_Data/T4_28_Traf6Nemo_Grid_1um_32mol/Bins_Diff:1/4,4, min_lifetime: 200, maxlifetime: 1200.csv'
# Out:
# 'Potrait saved as a png'
